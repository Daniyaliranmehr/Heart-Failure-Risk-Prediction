# %% [markdown]
# #### Libraries

# %%
# Prevent OpenMP runtime conflict between libraries like PyTorch, TensorFlow, and NumPy on Windows
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import sys
sys.path.append(os.path.abspath(".."))

from libraries import torch, nn, optim, Accuracy, DataLoader, plt

# %% [markdown]
# #### Load variables

# %%
vars = torch.load('../saved_values/variables.pt', weights_only=False)
train_dataset = vars['train_dataset']
valid_loader = vars['valid_loader']

# %% [markdown]
# #### Utils

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# #### MLP model with layers: 2, 3, 4

# %%
def multi_layer_model(num_layer):
    """Initialize mlp model with different layers"""
    in_features = 12
    out_features = 1
    h1 = 64
    h2 = 32
    h3 = 16
    h4 = 8

    if num_layer == 2:
        model = nn.Sequential(nn.Linear(in_features, h1),
                            nn.ReLU(),
                            nn.Linear(h1, h2),
                            nn.ReLU(),
                            nn.Linear(h2, out_features),
                            nn.Sigmoid())
        return model

    elif num_layer == 3:
        model = nn.Sequential(nn.Linear(in_features, h1),
                            nn.ReLU(),
                            nn.Linear(h1, h2),
                            nn.ReLU(),
                            nn.Linear(h2, h3),
                            nn.ReLU(),
                            nn.Linear(h3, out_features),
                            nn.Sigmoid())
        return model
    
    elif num_layer == 4:
        model = nn.Sequential(nn.Linear(in_features, h1),
                        nn.ReLU(),
                        nn.Linear(h1, h2),
                        nn.ReLU(),
                        nn.Linear(h2, h3),
                        nn.ReLU(),
                        nn.Linear(h3, h4),
                        nn.ReLU(),
                        nn.Linear(h4, out_features),
                        nn.Sigmoid())
        return model

# %% [markdown]
# #### Train model for different number of hidden layers: 2, 3, 4

# %%
loss_train_hist = []
loss_valid_hist = []

acc_train_hist = []
acc_valid_hist = []

num_epochs = 600
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
loss_fn = nn.BCELoss()

for num_layer in [2, 3, 4]:
    model = multi_layer_model(num_layer)
    optimizer = optim.SGD(model.parameters(), lr=0.001)

    for epoch in range(num_epochs):
        loss_train = AverageMeter()
        acc_train = Accuracy(task='binary')
        
        for inputs, targets in train_loader:
            outputs = model(inputs)
            loss = loss_fn(outputs.squeeze(), targets)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            loss_train.update(loss.item())
            acc_train(outputs.squeeze(), targets)

        loss_train_hist.append(loss_train.avg)
        acc_train_hist.append(acc_train.compute())

    
        with torch.no_grad():
            loss_valid = AverageMeter()
            acc_valid = Accuracy(task='binary')
            
            for inputs, targets in valid_loader:
                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), targets)

                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), targets)

                loss_valid.update(loss.item())
                acc_valid(outputs.squeeze(), targets)

        loss_valid_hist.append(loss_valid.avg)
        acc_valid_hist.append(acc_valid.compute())

    
        if epoch % 10 == 0:
            print(f'Epoch: {epoch} | Number of Layers: {num_layer}')
            print(f'\tTrain Loss: {loss_train.avg:.4f} | Train Accuracy: {acc_train.compute():.4f}')
            print(f'\tValidation Loss: {loss_valid.avg:.4f} | Validation Accuracy: {acc_valid.compute():.4f}\n')
# Out:
# Epoch: 0 | Number of Layers: 2
# 	Train Loss: 0.7200 | Train Accuracy: 0.3116
# 	Validation Loss: 0.7162 | Validation Accuracy: 0.3417
#
# Epoch: 10 | Number of Layers: 2
# 	Train Loss: 0.6694 | Train Accuracy: 0.6784
# 	Validation Loss: 0.6676 | Validation Accuracy: 0.6834
#
# Epoch: 20 | Number of Layers: 2
# 	Train Loss: 0.6395 | Train Accuracy: 0.6884
# 	Validation Loss: 0.6379 | Validation Accuracy: 0.6834
#
# Epoch: 30 | Number of Layers: 2
# 	Train Loss: 0.6179 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6163 | Validation Accuracy: 0.6834
#
# Epoch: 40 | Number of Layers: 2
# 	Train Loss: 0.5996 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5981 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 2
# 	Train Loss: 0.5832 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5819 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 2
# 	Train Loss: 0.5669 | Train Accuracy: 0.6884
# 	Validation Loss: 0.5665 | Validation Accuracy: 0.6884
#
# Epoch: 70 | Number of Layers: 2
# 	Train Loss: 0.5516 | Train Accuracy: 0.6884
# 	Validation Loss: 0.5509 | Validation Accuracy: 0.6884
#
# Epoch: 80 | Number of Layers: 2
# 	Train Loss: 0.5393 | Train Accuracy: 0.6935
# 	Validation Loss: 0.5349 | Validation Accuracy: 0.6935
#
# Epoch: 90 | Number of Layers: 2
# 	Train Loss: 0.5197 | Train Accuracy: 0.7035
# 	Validation Loss: 0.5180 | Validation Accuracy: 0.7035
#
# Epoch: 100 | Number of Layers: 2
# 	Train Loss: 0.5021 | Train Accuracy: 0.7186
# 	Validation Loss: 0.5002 | Validation Accuracy: 0.7286
#
# Epoch: 110 | Number of Layers: 2
# 	Train Loss: 0.4845 | Train Accuracy: 0.7588
# 	Validation Loss: 0.4817 | Validation Accuracy: 0.7588
#
# Epoch: 120 | Number of Layers: 2
# 	Train Loss: 0.4647 | Train Accuracy: 0.7688
# 	Validation Loss: 0.4628 | Validation Accuracy: 0.7739
#
# Epoch: 130 | Number of Layers: 2
# 	Train Loss: 0.4469 | Train Accuracy: 0.7889
# 	Validation Loss: 0.4441 | Validation Accuracy: 0.7889
#
# Epoch: 140 | Number of Layers: 2
# 	Train Loss: 0.4263 | Train Accuracy: 0.8040
# 	Validation Loss: 0.4258 | Validation Accuracy: 0.8090
#
# Epoch: 150 | Number of Layers: 2
# 	Train Loss: 0.4107 | Train Accuracy: 0.8241
# 	Validation Loss: 0.4084 | Validation Accuracy: 0.8241
#
# Epoch: 160 | Number of Layers: 2
# 	Train Loss: 0.3938 | Train Accuracy: 0.8442
# 	Validation Loss: 0.3926 | Validation Accuracy: 0.8442
#
# Epoch: 170 | Number of Layers: 2
# 	Train Loss: 0.3810 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3785 | Validation Accuracy: 0.8844
#
# Epoch: 180 | Number of Layers: 2
# 	Train Loss: 0.3686 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3660 | Validation Accuracy: 0.8844
#
# Epoch: 190 | Number of Layers: 2
# 	Train Loss: 0.3573 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3551 | Validation Accuracy: 0.8794
#
# Epoch: 200 | Number of Layers: 2
# 	Train Loss: 0.3484 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3455 | Validation Accuracy: 0.8744
#
# Epoch: 210 | Number of Layers: 2
# 	Train Loss: 0.3390 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3371 | Validation Accuracy: 0.8794
#
# Epoch: 220 | Number of Layers: 2
# 	Train Loss: 0.3330 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3296 | Validation Accuracy: 0.8844
#
# Epoch: 230 | Number of Layers: 2
# 	Train Loss: 0.3240 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3229 | Validation Accuracy: 0.8844
#
# Epoch: 240 | Number of Layers: 2
# 	Train Loss: 0.3176 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3168 | Validation Accuracy: 0.8844
#
# Epoch: 250 | Number of Layers: 2
# 	Train Loss: 0.3136 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3112 | Validation Accuracy: 0.8894
#
# Epoch: 260 | Number of Layers: 2
# 	Train Loss: 0.3084 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3059 | Validation Accuracy: 0.8894
#
# Epoch: 270 | Number of Layers: 2
# 	Train Loss: 0.3037 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3010 | Validation Accuracy: 0.8894
#
# Epoch: 280 | Number of Layers: 2
# 	Train Loss: 0.2972 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2962 | Validation Accuracy: 0.8945
#
# Epoch: 290 | Number of Layers: 2
# 	Train Loss: 0.2932 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2916 | Validation Accuracy: 0.8894
#
# Epoch: 300 | Number of Layers: 2
# 	Train Loss: 0.2900 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2871 | Validation Accuracy: 0.8894
#
# Epoch: 310 | Number of Layers: 2
# 	Train Loss: 0.2840 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2827 | Validation Accuracy: 0.8894
#
# Epoch: 320 | Number of Layers: 2
# 	Train Loss: 0.2803 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2785 | Validation Accuracy: 0.8894
#
# Epoch: 330 | Number of Layers: 2
# 	Train Loss: 0.2764 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2742 | Validation Accuracy: 0.8945
#
# Epoch: 340 | Number of Layers: 2
# 	Train Loss: 0.2707 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2700 | Validation Accuracy: 0.8945
#
# Epoch: 350 | Number of Layers: 2
# 	Train Loss: 0.2664 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2658 | Validation Accuracy: 0.8945
#
# Epoch: 360 | Number of Layers: 2
# 	Train Loss: 0.2636 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2616 | Validation Accuracy: 0.8995
#
# Epoch: 370 | Number of Layers: 2
# 	Train Loss: 0.2592 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2574 | Validation Accuracy: 0.8995
#
# Epoch: 380 | Number of Layers: 2
# 	Train Loss: 0.2565 | Train Accuracy: 0.9045
# 	Validation Loss: 0.2533 | Validation Accuracy: 0.8995
#
# Epoch: 390 | Number of Layers: 2
# 	Train Loss: 0.2506 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2491 | Validation Accuracy: 0.9095
#
# Epoch: 400 | Number of Layers: 2
# 	Train Loss: 0.2456 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2449 | Validation Accuracy: 0.9095
#
# Epoch: 410 | Number of Layers: 2
# 	Train Loss: 0.2419 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2408 | Validation Accuracy: 0.9095
#
# Epoch: 420 | Number of Layers: 2
# 	Train Loss: 0.2402 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2367 | Validation Accuracy: 0.9095
#
# Epoch: 430 | Number of Layers: 2
# 	Train Loss: 0.2333 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2326 | Validation Accuracy: 0.9095
#
# Epoch: 440 | Number of Layers: 2
# 	Train Loss: 0.2302 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2286 | Validation Accuracy: 0.9095
#
# Epoch: 450 | Number of Layers: 2
# 	Train Loss: 0.2255 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2245 | Validation Accuracy: 0.9146
#
# Epoch: 460 | Number of Layers: 2
# 	Train Loss: 0.2212 | Train Accuracy: 0.9196
# 	Validation Loss: 0.2204 | Validation Accuracy: 0.9246
#
# Epoch: 470 | Number of Layers: 2
# 	Train Loss: 0.2185 | Train Accuracy: 0.9246
# 	Validation Loss: 0.2163 | Validation Accuracy: 0.9246
#
# Epoch: 480 | Number of Layers: 2
# 	Train Loss: 0.2131 | Train Accuracy: 0.9246
# 	Validation Loss: 0.2121 | Validation Accuracy: 0.9246
#
# Epoch: 490 | Number of Layers: 2
# 	Train Loss: 0.2102 | Train Accuracy: 0.9296
# 	Validation Loss: 0.2081 | Validation Accuracy: 0.9347
#
# Epoch: 500 | Number of Layers: 2
# 	Train Loss: 0.2096 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2042 | Validation Accuracy: 0.9347
#
# Epoch: 510 | Number of Layers: 2
# 	Train Loss: 0.2017 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2003 | Validation Accuracy: 0.9347
#
# Epoch: 520 | Number of Layers: 2
# 	Train Loss: 0.1980 | Train Accuracy: 0.9397
# 	Validation Loss: 0.1965 | Validation Accuracy: 0.9397
#
# Epoch: 530 | Number of Layers: 2
# 	Train Loss: 0.1936 | Train Accuracy: 0.9347
# 	Validation Loss: 0.1928 | Validation Accuracy: 0.9347
#
# Epoch: 540 | Number of Layers: 2
# 	Train Loss: 0.1907 | Train Accuracy: 0.9347
# 	Validation Loss: 0.1890 | Validation Accuracy: 0.9347
#
# Epoch: 550 | Number of Layers: 2
# 	Train Loss: 0.1864 | Train Accuracy: 0.9397
# 	Validation Loss: 0.1853 | Validation Accuracy: 0.9397
#
# Epoch: 560 | Number of Layers: 2
# 	Train Loss: 0.1828 | Train Accuracy: 0.9397
# 	Validation Loss: 0.1815 | Validation Accuracy: 0.9397
#
# Epoch: 570 | Number of Layers: 2
# 	Train Loss: 0.1799 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1778 | Validation Accuracy: 0.9447
#
# Epoch: 580 | Number of Layers: 2
# 	Train Loss: 0.1754 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1741 | Validation Accuracy: 0.9447
#
# Epoch: 590 | Number of Layers: 2
# 	Train Loss: 0.1719 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1705 | Validation Accuracy: 0.9497
#
# Epoch: 0 | Number of Layers: 3
# 	Train Loss: 0.7072 | Train Accuracy: 0.3216
# 	Validation Loss: 0.7054 | Validation Accuracy: 0.3216
#
# Epoch: 10 | Number of Layers: 3
# 	Train Loss: 0.6792 | Train Accuracy: 0.6884
# 	Validation Loss: 0.6779 | Validation Accuracy: 0.6985
#
# Epoch: 20 | Number of Layers: 3
# 	Train Loss: 0.6580 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6572 | Validation Accuracy: 0.6834
#
# Epoch: 30 | Number of Layers: 3
# 	Train Loss: 0.6426 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6415 | Validation Accuracy: 0.6834
#
# Epoch: 40 | Number of Layers: 3
# 	Train Loss: 0.6303 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6292 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 3
# 	Train Loss: 0.6208 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6192 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 3
# 	Train Loss: 0.6123 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6104 | Validation Accuracy: 0.6834
#
# Epoch: 70 | Number of Layers: 3
# 	Train Loss: 0.6041 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6020 | Validation Accuracy: 0.6834
#
# Epoch: 80 | Number of Layers: 3
# 	Train Loss: 0.5938 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5935 | Validation Accuracy: 0.6834
#
# Epoch: 90 | Number of Layers: 3
# 	Train Loss: 0.5854 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5843 | Validation Accuracy: 0.6834
#
# Epoch: 100 | Number of Layers: 3
# 	Train Loss: 0.5754 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5742 | Validation Accuracy: 0.6834
#
# Epoch: 110 | Number of Layers: 3
# 	Train Loss: 0.5635 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5632 | Validation Accuracy: 0.6834
#
# Epoch: 120 | Number of Layers: 3
# 	Train Loss: 0.5526 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5510 | Validation Accuracy: 0.6834
#
# Epoch: 130 | Number of Layers: 3
# 	Train Loss: 0.5398 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5372 | Validation Accuracy: 0.6834
#
# Epoch: 140 | Number of Layers: 3
# 	Train Loss: 0.5262 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5227 | Validation Accuracy: 0.6834
#
# Epoch: 150 | Number of Layers: 3
# 	Train Loss: 0.5107 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5075 | Validation Accuracy: 0.6834
#
# Epoch: 160 | Number of Layers: 3
# 	Train Loss: 0.4926 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4922 | Validation Accuracy: 0.6834
#
# Epoch: 170 | Number of Layers: 3
# 	Train Loss: 0.4786 | Train Accuracy: 0.6884
# 	Validation Loss: 0.4771 | Validation Accuracy: 0.6884
#
# Epoch: 180 | Number of Layers: 3
# 	Train Loss: 0.4642 | Train Accuracy: 0.7035
# 	Validation Loss: 0.4624 | Validation Accuracy: 0.7035
#
# Epoch: 190 | Number of Layers: 3
# 	Train Loss: 0.4513 | Train Accuracy: 0.7538
# 	Validation Loss: 0.4480 | Validation Accuracy: 0.7538
#
# Epoch: 200 | Number of Layers: 3
# 	Train Loss: 0.4353 | Train Accuracy: 0.7839
# 	Validation Loss: 0.4339 | Validation Accuracy: 0.7889
#
# Epoch: 210 | Number of Layers: 3
# 	Train Loss: 0.4201 | Train Accuracy: 0.8141
# 	Validation Loss: 0.4200 | Validation Accuracy: 0.8141
#
# Epoch: 220 | Number of Layers: 3
# 	Train Loss: 0.4072 | Train Accuracy: 0.8492
# 	Validation Loss: 0.4066 | Validation Accuracy: 0.8543
#
# Epoch: 230 | Number of Layers: 3
# 	Train Loss: 0.3950 | Train Accuracy: 0.8492
# 	Validation Loss: 0.3939 | Validation Accuracy: 0.8492
#
# Epoch: 240 | Number of Layers: 3
# 	Train Loss: 0.3839 | Train Accuracy: 0.8543
# 	Validation Loss: 0.3816 | Validation Accuracy: 0.8543
#
# Epoch: 250 | Number of Layers: 3
# 	Train Loss: 0.3705 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3699 | Validation Accuracy: 0.8643
#
# Epoch: 260 | Number of Layers: 3
# 	Train Loss: 0.3591 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3587 | Validation Accuracy: 0.8693
#
# Epoch: 270 | Number of Layers: 3
# 	Train Loss: 0.3510 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3483 | Validation Accuracy: 0.8844
#
# Epoch: 280 | Number of Layers: 3
# 	Train Loss: 0.3398 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3385 | Validation Accuracy: 0.8744
#
# Epoch: 290 | Number of Layers: 3
# 	Train Loss: 0.3309 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3294 | Validation Accuracy: 0.8744
#
# Epoch: 300 | Number of Layers: 3
# 	Train Loss: 0.3233 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3209 | Validation Accuracy: 0.8643
#
# Epoch: 310 | Number of Layers: 3
# 	Train Loss: 0.3140 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3131 | Validation Accuracy: 0.8643
#
# Epoch: 320 | Number of Layers: 3
# 	Train Loss: 0.3071 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3058 | Validation Accuracy: 0.8693
#
# Epoch: 330 | Number of Layers: 3
# 	Train Loss: 0.3007 | Train Accuracy: 0.8744
# 	Validation Loss: 0.2990 | Validation Accuracy: 0.8744
#
# Epoch: 340 | Number of Layers: 3
# 	Train Loss: 0.2952 | Train Accuracy: 0.8744
# 	Validation Loss: 0.2926 | Validation Accuracy: 0.8744
#
# Epoch: 350 | Number of Layers: 3
# 	Train Loss: 0.2872 | Train Accuracy: 0.8744
# 	Validation Loss: 0.2864 | Validation Accuracy: 0.8744
#
# Epoch: 360 | Number of Layers: 3
# 	Train Loss: 0.2853 | Train Accuracy: 0.8744
# 	Validation Loss: 0.2805 | Validation Accuracy: 0.8744
#
# Epoch: 370 | Number of Layers: 3
# 	Train Loss: 0.2763 | Train Accuracy: 0.8744
# 	Validation Loss: 0.2748 | Validation Accuracy: 0.8744
#
# Epoch: 380 | Number of Layers: 3
# 	Train Loss: 0.2730 | Train Accuracy: 0.8844
# 	Validation Loss: 0.2694 | Validation Accuracy: 0.8794
#
# Epoch: 390 | Number of Layers: 3
# 	Train Loss: 0.2663 | Train Accuracy: 0.8844
# 	Validation Loss: 0.2640 | Validation Accuracy: 0.8844
#
# Epoch: 400 | Number of Layers: 3
# 	Train Loss: 0.2597 | Train Accuracy: 0.8844
# 	Validation Loss: 0.2587 | Validation Accuracy: 0.8844
#
# Epoch: 410 | Number of Layers: 3
# 	Train Loss: 0.2613 | Train Accuracy: 0.8844
# 	Validation Loss: 0.2535 | Validation Accuracy: 0.8844
#
# Epoch: 420 | Number of Layers: 3
# 	Train Loss: 0.2521 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2484 | Validation Accuracy: 0.8995
#
# Epoch: 430 | Number of Layers: 3
# 	Train Loss: 0.2451 | Train Accuracy: 0.9045
# 	Validation Loss: 0.2433 | Validation Accuracy: 0.9045
#
# Epoch: 440 | Number of Layers: 3
# 	Train Loss: 0.2429 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2383 | Validation Accuracy: 0.9196
#
# Epoch: 450 | Number of Layers: 3
# 	Train Loss: 0.2350 | Train Accuracy: 0.9246
# 	Validation Loss: 0.2333 | Validation Accuracy: 0.9397
#
# Epoch: 460 | Number of Layers: 3
# 	Train Loss: 0.2302 | Train Accuracy: 0.9397
# 	Validation Loss: 0.2281 | Validation Accuracy: 0.9347
#
# Epoch: 470 | Number of Layers: 3
# 	Train Loss: 0.2272 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2229 | Validation Accuracy: 0.9347
#
# Epoch: 480 | Number of Layers: 3
# 	Train Loss: 0.2195 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2173 | Validation Accuracy: 0.9347
#
# Epoch: 490 | Number of Layers: 3
# 	Train Loss: 0.2136 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2114 | Validation Accuracy: 0.9347
#
# Epoch: 500 | Number of Layers: 3
# 	Train Loss: 0.2077 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2056 | Validation Accuracy: 0.9347
#
# Epoch: 510 | Number of Layers: 3
# 	Train Loss: 0.2012 | Train Accuracy: 0.9397
# 	Validation Loss: 0.1996 | Validation Accuracy: 0.9397
#
# Epoch: 520 | Number of Layers: 3
# 	Train Loss: 0.1955 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1938 | Validation Accuracy: 0.9447
#
# Epoch: 530 | Number of Layers: 3
# 	Train Loss: 0.1909 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1883 | Validation Accuracy: 0.9497
#
# Epoch: 540 | Number of Layers: 3
# 	Train Loss: 0.1852 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1831 | Validation Accuracy: 0.9497
#
# Epoch: 550 | Number of Layers: 3
# 	Train Loss: 0.1795 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1781 | Validation Accuracy: 0.9497
#
# Epoch: 560 | Number of Layers: 3
# 	Train Loss: 0.1748 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1732 | Validation Accuracy: 0.9497
#
# Epoch: 570 | Number of Layers: 3
# 	Train Loss: 0.1702 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1684 | Validation Accuracy: 0.9447
#
# Epoch: 580 | Number of Layers: 3
# 	Train Loss: 0.1655 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1637 | Validation Accuracy: 0.9447
#
# Epoch: 590 | Number of Layers: 3
# 	Train Loss: 0.1609 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1591 | Validation Accuracy: 0.9447
#
# Epoch: 0 | Number of Layers: 4
# 	Train Loss: 0.6644 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6633 | Validation Accuracy: 0.6834
#
# Epoch: 10 | Number of Layers: 4
# 	Train Loss: 0.6532 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6529 | Validation Accuracy: 0.6834
#
# Epoch: 20 | Number of Layers: 4
# 	Train Loss: 0.6457 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6450 | Validation Accuracy: 0.6834
#
# Epoch: 30 | Number of Layers: 4
# 	Train Loss: 0.6403 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6390 | Validation Accuracy: 0.6834
#
# Epoch: 40 | Number of Layers: 4
# 	Train Loss: 0.6351 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6344 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 4
# 	Train Loss: 0.6316 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6309 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 4
# 	Train Loss: 0.6288 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6282 | Validation Accuracy: 0.6834
#
# Epoch: 70 | Number of Layers: 4
# 	Train Loss: 0.6267 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6260 | Validation Accuracy: 0.6834
#
# Epoch: 80 | Number of Layers: 4
# 	Train Loss: 0.6239 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6242 | Validation Accuracy: 0.6834
#
# Epoch: 90 | Number of Layers: 4
# 	Train Loss: 0.6234 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6227 | Validation Accuracy: 0.6834
#
# Epoch: 100 | Number of Layers: 4
# 	Train Loss: 0.6220 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6214 | Validation Accuracy: 0.6834
#
# Epoch: 110 | Number of Layers: 4
# 	Train Loss: 0.6198 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6202 | Validation Accuracy: 0.6834
#
# Epoch: 120 | Number of Layers: 4
# 	Train Loss: 0.6186 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6190 | Validation Accuracy: 0.6834
#
# Epoch: 130 | Number of Layers: 4
# 	Train Loss: 0.6186 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6178 | Validation Accuracy: 0.6834
#
# Epoch: 140 | Number of Layers: 4
# 	Train Loss: 0.6174 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6166 | Validation Accuracy: 0.6834
#
# Epoch: 150 | Number of Layers: 4
# 	Train Loss: 0.6162 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6153 | Validation Accuracy: 0.6834
#
# Epoch: 160 | Number of Layers: 4
# 	Train Loss: 0.6135 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6139 | Validation Accuracy: 0.6834
#
# Epoch: 170 | Number of Layers: 4
# 	Train Loss: 0.6131 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6123 | Validation Accuracy: 0.6834
#
# Epoch: 180 | Number of Layers: 4
# 	Train Loss: 0.6113 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6105 | Validation Accuracy: 0.6834
#
# Epoch: 190 | Number of Layers: 4
# 	Train Loss: 0.6093 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6084 | Validation Accuracy: 0.6834
#
# Epoch: 200 | Number of Layers: 4
# 	Train Loss: 0.6057 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6060 | Validation Accuracy: 0.6834
#
# Epoch: 210 | Number of Layers: 4
# 	Train Loss: 0.6030 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6033 | Validation Accuracy: 0.6834
#
# Epoch: 220 | Number of Layers: 4
# 	Train Loss: 0.6023 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6002 | Validation Accuracy: 0.6834
#
# Epoch: 230 | Number of Layers: 4
# 	Train Loss: 0.5977 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5966 | Validation Accuracy: 0.6834
#
# Epoch: 240 | Number of Layers: 4
# 	Train Loss: 0.5922 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5924 | Validation Accuracy: 0.6834
#
# Epoch: 250 | Number of Layers: 4
# 	Train Loss: 0.5898 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5876 | Validation Accuracy: 0.6834
#
# Epoch: 260 | Number of Layers: 4
# 	Train Loss: 0.5819 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5820 | Validation Accuracy: 0.6834
#
# Epoch: 270 | Number of Layers: 4
# 	Train Loss: 0.5752 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5755 | Validation Accuracy: 0.6834
#
# Epoch: 280 | Number of Layers: 4
# 	Train Loss: 0.5696 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5681 | Validation Accuracy: 0.6834
#
# Epoch: 290 | Number of Layers: 4
# 	Train Loss: 0.5622 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5600 | Validation Accuracy: 0.6834
#
# Epoch: 300 | Number of Layers: 4
# 	Train Loss: 0.5513 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5512 | Validation Accuracy: 0.6834
#
# Epoch: 310 | Number of Layers: 4
# 	Train Loss: 0.5432 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5416 | Validation Accuracy: 0.6834
#
# Epoch: 320 | Number of Layers: 4
# 	Train Loss: 0.5336 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5312 | Validation Accuracy: 0.6834
#
# Epoch: 330 | Number of Layers: 4
# 	Train Loss: 0.5215 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5200 | Validation Accuracy: 0.6834
#
# Epoch: 340 | Number of Layers: 4
# 	Train Loss: 0.5092 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5084 | Validation Accuracy: 0.6834
#
# Epoch: 350 | Number of Layers: 4
# 	Train Loss: 0.5003 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4965 | Validation Accuracy: 0.6834
#
# Epoch: 360 | Number of Layers: 4
# 	Train Loss: 0.4854 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4847 | Validation Accuracy: 0.6834
#
# Epoch: 370 | Number of Layers: 4
# 	Train Loss: 0.4751 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4733 | Validation Accuracy: 0.6834
#
# Epoch: 380 | Number of Layers: 4
# 	Train Loss: 0.4645 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4617 | Validation Accuracy: 0.6834
#
# Epoch: 390 | Number of Layers: 4
# 	Train Loss: 0.4529 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4506 | Validation Accuracy: 0.6834
#
# Epoch: 400 | Number of Layers: 4
# 	Train Loss: 0.4420 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4403 | Validation Accuracy: 0.6834
#
# Epoch: 410 | Number of Layers: 4
# 	Train Loss: 0.4330 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4308 | Validation Accuracy: 0.6834
#
# Epoch: 420 | Number of Layers: 4
# 	Train Loss: 0.4235 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4218 | Validation Accuracy: 0.6834
#
# Epoch: 430 | Number of Layers: 4
# 	Train Loss: 0.4160 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4134 | Validation Accuracy: 0.6834
#
# Epoch: 440 | Number of Layers: 4
# 	Train Loss: 0.4084 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4052 | Validation Accuracy: 0.6834
#
# Epoch: 450 | Number of Layers: 4
# 	Train Loss: 0.3977 | Train Accuracy: 0.6834
# 	Validation Loss: 0.3973 | Validation Accuracy: 0.6834
#
# Epoch: 460 | Number of Layers: 4
# 	Train Loss: 0.3909 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3897 | Validation Accuracy: 0.8794
#
# Epoch: 470 | Number of Layers: 4
# 	Train Loss: 0.3833 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3824 | Validation Accuracy: 0.8794
#
# Epoch: 480 | Number of Layers: 4
# 	Train Loss: 0.3761 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3751 | Validation Accuracy: 0.8894
#
# Epoch: 490 | Number of Layers: 4
# 	Train Loss: 0.3705 | Train Accuracy: 0.8945
# 	Validation Loss: 0.3679 | Validation Accuracy: 0.8894
#
# Epoch: 500 | Number of Layers: 4
# 	Train Loss: 0.3626 | Train Accuracy: 0.8945
# 	Validation Loss: 0.3609 | Validation Accuracy: 0.8995
#
# Epoch: 510 | Number of Layers: 4
# 	Train Loss: 0.3568 | Train Accuracy: 0.8945
# 	Validation Loss: 0.3539 | Validation Accuracy: 0.8995
#
# Epoch: 520 | Number of Layers: 4
# 	Train Loss: 0.3484 | Train Accuracy: 0.8945
# 	Validation Loss: 0.3471 | Validation Accuracy: 0.8945
#
# Epoch: 530 | Number of Layers: 4
# 	Train Loss: 0.3434 | Train Accuracy: 0.9045
# 	Validation Loss: 0.3402 | Validation Accuracy: 0.9045
#
# Epoch: 540 | Number of Layers: 4
# 	Train Loss: 0.3340 | Train Accuracy: 0.9095
# 	Validation Loss: 0.3335 | Validation Accuracy: 0.9146
#
# Epoch: 550 | Number of Layers: 4
# 	Train Loss: 0.3290 | Train Accuracy: 0.9146
# 	Validation Loss: 0.3267 | Validation Accuracy: 0.9146
#
# Epoch: 560 | Number of Layers: 4
# 	Train Loss: 0.3214 | Train Accuracy: 0.9146
# 	Validation Loss: 0.3199 | Validation Accuracy: 0.9146
#
# Epoch: 570 | Number of Layers: 4
# 	Train Loss: 0.3161 | Train Accuracy: 0.9146
# 	Validation Loss: 0.3131 | Validation Accuracy: 0.9196
#
# Epoch: 580 | Number of Layers: 4
# 	Train Loss: 0.3082 | Train Accuracy: 0.9246
# 	Validation Loss: 0.3063 | Validation Accuracy: 0.9296
#
# Epoch: 590 | Number of Layers: 4
# 	Train Loss: 0.3018 | Train Accuracy: 0.9296
# 	Validation Loss: 0.2993 | Validation Accuracy: 0.9296

# %%
plt.figure(figsize=(10,6))

colors = ['darkblue', 'darkred', 'darkgreen']
light_colors = ['skyblue', 'salmon', 'limegreen']
layers = [2, 3, 4]

for i, num_layer in enumerate(layers):

    start = i * num_epochs
    end = (i + 1) * num_epochs

    # Train Loss
    plt.plot(
        range(num_epochs),
        loss_train_hist[start:end],
        color=colors[i],
        linewidth=2,
        marker='o',
        label=f'train_layers={num_layer}'
    )

    # Validation Loss
    plt.plot(
        range(num_epochs),
        loss_valid_hist[start:end],
        color=light_colors[i],
        linewidth=2,
        linestyle='--',
        marker='x',
        label=f'valid_layers={num_layer}'
    )

plt.title("Effect of Number of Hidden Layers on Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.grid(True, linestyle=':')
plt.legend()
plt.tight_layout()

plt.show()
