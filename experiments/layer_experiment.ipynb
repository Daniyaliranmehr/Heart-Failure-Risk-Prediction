# %% [markdown]
# #### Libraries

# %%
# Prevent OpenMP runtime conflict between libraries like PyTorch, TensorFlow, and NumPy on Windows
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import sys
sys.path.append(os.path.abspath(".."))

from libraries import torch, nn, optim, Accuracy, DataLoader, plt

# %% [markdown]
# #### Load variables

# %%
vars = torch.load('../saved_values/variables.pt', weights_only=False)
train_dataset = vars['train_dataset']
valid_loader = vars['valid_loader']

# %% [markdown]
# #### Utils

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# #### MLP model with layers: 2, 3, 4

# %%
def multi_layer_model(num_layer):
    """Initialize mlp model with different layers"""
    in_features = 12
    out_features = 1
    h1 = 64
    h2 = 32
    h3 = 16
    h4 = 8

    if num_layer == 2:
        model = nn.Sequential(nn.Linear(in_features, h1),
                            nn.ReLU(),
                            nn.Linear(h1, h2),
                            nn.ReLU(),
                            nn.Linear(h2, out_features),
                            nn.Sigmoid())
        return model

    elif num_layer == 3:
        model = nn.Sequential(nn.Linear(in_features, h1),
                            nn.ReLU(),
                            nn.Linear(h1, h2),
                            nn.ReLU(),
                            nn.Linear(h2, h3),
                            nn.ReLU(),
                            nn.Linear(h3, out_features),
                            nn.Sigmoid())
        return model
    
    elif num_layer == 4:
        model = nn.Sequential(nn.Linear(in_features, h1),
                        nn.ReLU(),
                        nn.Linear(h1, h2),
                        nn.ReLU(),
                        nn.Linear(h2, h3),
                        nn.ReLU(),
                        nn.Linear(h3, h4),
                        nn.ReLU(),
                        nn.Linear(h4, out_features),
                        nn.Sigmoid())
        return model

# %% [markdown]
# #### Train model for different number of hidden layers: 2, 3, 4

# %%
loss_train_hist = []
loss_valid_hist = []

acc_train_hist = []
acc_valid_hist = []

num_epochs = 600
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
loss_fn = nn.BCELoss()

for num_layer in [2, 3, 4]:
    model = multi_layer_model(num_layer)
    optimizer = optim.SGD(model.parameters(), lr=0.001)

    for epoch in range(num_epochs):
        loss_train = AverageMeter()
        acc_train = Accuracy(task='binary')
        
        for inputs, targets in train_loader:
            outputs = model(inputs)
            loss = loss_fn(outputs.squeeze(), targets)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            loss_train.update(loss.item())
            acc_train(outputs.squeeze(), targets)

        loss_train_hist.append(loss_train.avg)
        acc_train_hist.append(acc_train.compute())

    
        with torch.no_grad():
            loss_valid = AverageMeter()
            acc_valid = Accuracy(task='binary')
            
            for inputs, targets in valid_loader:
                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), targets)

                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), targets)

                loss_valid.update(loss.item())
                acc_valid(outputs.squeeze(), targets)

        loss_valid_hist.append(loss_valid.avg)
        acc_valid_hist.append(acc_valid.compute())

    
        if epoch % 10 == 0:
            print(f'Epoch: {epoch} | Number of Layers: {num_layer}')
            print(f'\tTrain Loss: {loss_train.avg:.4f} | Train Accuracy: {acc_train.compute():.4f}')
            print(f'\tValidation Loss: {loss_valid.avg:.4f} | Validation Accuracy: {acc_valid.compute():.4f}\n')
# Out:
# Epoch: 0 | Number of Layers: 2
# 	Train Loss: 0.6997 | Train Accuracy: 0.3668
# 	Validation Loss: 0.6977 | Validation Accuracy: 0.3869
#
# Epoch: 10 | Number of Layers: 2
# 	Train Loss: 0.6696 | Train Accuracy: 0.6985
# 	Validation Loss: 0.6684 | Validation Accuracy: 0.6985
#
# Epoch: 20 | Number of Layers: 2
# 	Train Loss: 0.6495 | Train Accuracy: 0.6935
# 	Validation Loss: 0.6483 | Validation Accuracy: 0.6935
#
# Epoch: 30 | Number of Layers: 2
# 	Train Loss: 0.6346 | Train Accuracy: 0.6884
# 	Validation Loss: 0.6330 | Validation Accuracy: 0.6884
#
# Epoch: 40 | Number of Layers: 2
# 	Train Loss: 0.6219 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6201 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 2
# 	Train Loss: 0.6092 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6079 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 2
# 	Train Loss: 0.5963 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5957 | Validation Accuracy: 0.6834
#
# Epoch: 70 | Number of Layers: 2
# 	Train Loss: 0.5849 | Train Accuracy: 0.6884
# 	Validation Loss: 0.5833 | Validation Accuracy: 0.6884
#
# Epoch: 80 | Number of Layers: 2
# 	Train Loss: 0.5731 | Train Accuracy: 0.6884
# 	Validation Loss: 0.5703 | Validation Accuracy: 0.6884
#
# Epoch: 90 | Number of Layers: 2
# 	Train Loss: 0.5583 | Train Accuracy: 0.7035
# 	Validation Loss: 0.5565 | Validation Accuracy: 0.7085
#
# Epoch: 100 | Number of Layers: 2
# 	Train Loss: 0.5438 | Train Accuracy: 0.7136
# 	Validation Loss: 0.5415 | Validation Accuracy: 0.7186
#
# Epoch: 110 | Number of Layers: 2
# 	Train Loss: 0.5280 | Train Accuracy: 0.7236
# 	Validation Loss: 0.5255 | Validation Accuracy: 0.7286
#
# Epoch: 120 | Number of Layers: 2
# 	Train Loss: 0.5104 | Train Accuracy: 0.7638
# 	Validation Loss: 0.5087 | Validation Accuracy: 0.7688
#
# Epoch: 130 | Number of Layers: 2
# 	Train Loss: 0.4937 | Train Accuracy: 0.7789
# 	Validation Loss: 0.4912 | Validation Accuracy: 0.7839
#
# Epoch: 140 | Number of Layers: 2
# 	Train Loss: 0.4745 | Train Accuracy: 0.7839
# 	Validation Loss: 0.4736 | Validation Accuracy: 0.7839
#
# Epoch: 150 | Number of Layers: 2
# 	Train Loss: 0.4618 | Train Accuracy: 0.8141
# 	Validation Loss: 0.4565 | Validation Accuracy: 0.8141
#
# Epoch: 160 | Number of Layers: 2
# 	Train Loss: 0.4407 | Train Accuracy: 0.8241
# 	Validation Loss: 0.4401 | Validation Accuracy: 0.8241
#
# Epoch: 170 | Number of Layers: 2
# 	Train Loss: 0.4270 | Train Accuracy: 0.8191
# 	Validation Loss: 0.4250 | Validation Accuracy: 0.8241
#
# Epoch: 180 | Number of Layers: 2
# 	Train Loss: 0.4136 | Train Accuracy: 0.8291
# 	Validation Loss: 0.4112 | Validation Accuracy: 0.8291
#
# Epoch: 190 | Number of Layers: 2
# 	Train Loss: 0.4006 | Train Accuracy: 0.8492
# 	Validation Loss: 0.3990 | Validation Accuracy: 0.8492
#
# Epoch: 200 | Number of Layers: 2
# 	Train Loss: 0.3905 | Train Accuracy: 0.8492
# 	Validation Loss: 0.3883 | Validation Accuracy: 0.8492
#
# Epoch: 210 | Number of Layers: 2
# 	Train Loss: 0.3810 | Train Accuracy: 0.8442
# 	Validation Loss: 0.3789 | Validation Accuracy: 0.8492
#
# Epoch: 220 | Number of Layers: 2
# 	Train Loss: 0.3728 | Train Accuracy: 0.8543
# 	Validation Loss: 0.3706 | Validation Accuracy: 0.8593
#
# Epoch: 230 | Number of Layers: 2
# 	Train Loss: 0.3644 | Train Accuracy: 0.8593
# 	Validation Loss: 0.3634 | Validation Accuracy: 0.8593
#
# Epoch: 240 | Number of Layers: 2
# 	Train Loss: 0.3590 | Train Accuracy: 0.8593
# 	Validation Loss: 0.3571 | Validation Accuracy: 0.8593
#
# Epoch: 250 | Number of Layers: 2
# 	Train Loss: 0.3523 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3514 | Validation Accuracy: 0.8693
#
# Epoch: 260 | Number of Layers: 2
# 	Train Loss: 0.3486 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3463 | Validation Accuracy: 0.8643
#
# Epoch: 270 | Number of Layers: 2
# 	Train Loss: 0.3431 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3416 | Validation Accuracy: 0.8744
#
# Epoch: 280 | Number of Layers: 2
# 	Train Loss: 0.3376 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3373 | Validation Accuracy: 0.8744
#
# Epoch: 290 | Number of Layers: 2
# 	Train Loss: 0.3340 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3332 | Validation Accuracy: 0.8744
#
# Epoch: 300 | Number of Layers: 2
# 	Train Loss: 0.3319 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3294 | Validation Accuracy: 0.8794
#
# Epoch: 310 | Number of Layers: 2
# 	Train Loss: 0.3294 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3259 | Validation Accuracy: 0.8794
#
# Epoch: 320 | Number of Layers: 2
# 	Train Loss: 0.3232 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3224 | Validation Accuracy: 0.8794
#
# Epoch: 330 | Number of Layers: 2
# 	Train Loss: 0.3243 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3190 | Validation Accuracy: 0.8794
#
# Epoch: 340 | Number of Layers: 2
# 	Train Loss: 0.3160 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3156 | Validation Accuracy: 0.8844
#
# Epoch: 350 | Number of Layers: 2
# 	Train Loss: 0.3129 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3123 | Validation Accuracy: 0.8844
#
# Epoch: 360 | Number of Layers: 2
# 	Train Loss: 0.3108 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3090 | Validation Accuracy: 0.8894
#
# Epoch: 370 | Number of Layers: 2
# 	Train Loss: 0.3067 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3058 | Validation Accuracy: 0.8844
#
# Epoch: 380 | Number of Layers: 2
# 	Train Loss: 0.3045 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3026 | Validation Accuracy: 0.8794
#
# Epoch: 390 | Number of Layers: 2
# 	Train Loss: 0.3034 | Train Accuracy: 0.8794
# 	Validation Loss: 0.2993 | Validation Accuracy: 0.8794
#
# Epoch: 400 | Number of Layers: 2
# 	Train Loss: 0.2970 | Train Accuracy: 0.8794
# 	Validation Loss: 0.2961 | Validation Accuracy: 0.8794
#
# Epoch: 410 | Number of Layers: 2
# 	Train Loss: 0.2954 | Train Accuracy: 0.8794
# 	Validation Loss: 0.2929 | Validation Accuracy: 0.8794
#
# Epoch: 420 | Number of Layers: 2
# 	Train Loss: 0.2908 | Train Accuracy: 0.8794
# 	Validation Loss: 0.2896 | Validation Accuracy: 0.8794
#
# Epoch: 430 | Number of Layers: 2
# 	Train Loss: 0.2880 | Train Accuracy: 0.8844
# 	Validation Loss: 0.2863 | Validation Accuracy: 0.8844
#
# Epoch: 440 | Number of Layers: 2
# 	Train Loss: 0.2861 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2829 | Validation Accuracy: 0.8894
#
# Epoch: 450 | Number of Layers: 2
# 	Train Loss: 0.2817 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2796 | Validation Accuracy: 0.8894
#
# Epoch: 460 | Number of Layers: 2
# 	Train Loss: 0.2771 | Train Accuracy: 0.8894
# 	Validation Loss: 0.2762 | Validation Accuracy: 0.8945
#
# Epoch: 470 | Number of Layers: 2
# 	Train Loss: 0.2737 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2728 | Validation Accuracy: 0.8945
#
# Epoch: 480 | Number of Layers: 2
# 	Train Loss: 0.2702 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2694 | Validation Accuracy: 0.8945
#
# Epoch: 490 | Number of Layers: 2
# 	Train Loss: 0.2667 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2659 | Validation Accuracy: 0.8945
#
# Epoch: 500 | Number of Layers: 2
# 	Train Loss: 0.2633 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2624 | Validation Accuracy: 0.8945
#
# Epoch: 510 | Number of Layers: 2
# 	Train Loss: 0.2603 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2589 | Validation Accuracy: 0.8945
#
# Epoch: 520 | Number of Layers: 2
# 	Train Loss: 0.2567 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2554 | Validation Accuracy: 0.8995
#
# Epoch: 530 | Number of Layers: 2
# 	Train Loss: 0.2558 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2518 | Validation Accuracy: 0.8995
#
# Epoch: 540 | Number of Layers: 2
# 	Train Loss: 0.2494 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2483 | Validation Accuracy: 0.8995
#
# Epoch: 550 | Number of Layers: 2
# 	Train Loss: 0.2458 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2447 | Validation Accuracy: 0.8995
#
# Epoch: 560 | Number of Layers: 2
# 	Train Loss: 0.2418 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2410 | Validation Accuracy: 0.8995
#
# Epoch: 570 | Number of Layers: 2
# 	Train Loss: 0.2390 | Train Accuracy: 0.8995
# 	Validation Loss: 0.2374 | Validation Accuracy: 0.8995
#
# Epoch: 580 | Number of Layers: 2
# 	Train Loss: 0.2349 | Train Accuracy: 0.9045
# 	Validation Loss: 0.2337 | Validation Accuracy: 0.9045
#
# Epoch: 590 | Number of Layers: 2
# 	Train Loss: 0.2312 | Train Accuracy: 0.9045
# 	Validation Loss: 0.2300 | Validation Accuracy: 0.9045
#
# Epoch: 0 | Number of Layers: 3
# 	Train Loss: 0.6894 | Train Accuracy: 0.6432
# 	Validation Loss: 0.6881 | Validation Accuracy: 0.6533
#
# Epoch: 10 | Number of Layers: 3
# 	Train Loss: 0.6684 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6671 | Validation Accuracy: 0.6834
#
# Epoch: 20 | Number of Layers: 3
# 	Train Loss: 0.6526 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6516 | Validation Accuracy: 0.6834
#
# Epoch: 30 | Number of Layers: 3
# 	Train Loss: 0.6413 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6398 | Validation Accuracy: 0.6834
#
# Epoch: 40 | Number of Layers: 3
# 	Train Loss: 0.6306 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6304 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 3
# 	Train Loss: 0.6245 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6228 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 3
# 	Train Loss: 0.6159 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6158 | Validation Accuracy: 0.6834
#
# Epoch: 70 | Number of Layers: 3
# 	Train Loss: 0.6103 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6091 | Validation Accuracy: 0.6834
#
# Epoch: 80 | Number of Layers: 3
# 	Train Loss: 0.6021 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6021 | Validation Accuracy: 0.6834
#
# Epoch: 90 | Number of Layers: 3
# 	Train Loss: 0.5954 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5943 | Validation Accuracy: 0.6834
#
# Epoch: 100 | Number of Layers: 3
# 	Train Loss: 0.5866 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5853 | Validation Accuracy: 0.6834
#
# Epoch: 110 | Number of Layers: 3
# 	Train Loss: 0.5763 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5752 | Validation Accuracy: 0.6834
#
# Epoch: 120 | Number of Layers: 3
# 	Train Loss: 0.5646 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5643 | Validation Accuracy: 0.6834
#
# Epoch: 130 | Number of Layers: 3
# 	Train Loss: 0.5524 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5521 | Validation Accuracy: 0.6834
#
# Epoch: 140 | Number of Layers: 3
# 	Train Loss: 0.5392 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5387 | Validation Accuracy: 0.6834
#
# Epoch: 150 | Number of Layers: 3
# 	Train Loss: 0.5257 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5245 | Validation Accuracy: 0.6834
#
# Epoch: 160 | Number of Layers: 3
# 	Train Loss: 0.5108 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5103 | Validation Accuracy: 0.6834
#
# Epoch: 170 | Number of Layers: 3
# 	Train Loss: 0.4963 | Train Accuracy: 0.6834
# 	Validation Loss: 0.4960 | Validation Accuracy: 0.6834
#
# Epoch: 180 | Number of Layers: 3
# 	Train Loss: 0.4824 | Train Accuracy: 0.6884
# 	Validation Loss: 0.4820 | Validation Accuracy: 0.6935
#
# Epoch: 190 | Number of Layers: 3
# 	Train Loss: 0.4711 | Train Accuracy: 0.7085
# 	Validation Loss: 0.4682 | Validation Accuracy: 0.7085
#
# Epoch: 200 | Number of Layers: 3
# 	Train Loss: 0.4556 | Train Accuracy: 0.7337
# 	Validation Loss: 0.4548 | Validation Accuracy: 0.7337
#
# Epoch: 210 | Number of Layers: 3
# 	Train Loss: 0.4463 | Train Accuracy: 0.7789
# 	Validation Loss: 0.4417 | Validation Accuracy: 0.7889
#
# Epoch: 220 | Number of Layers: 3
# 	Train Loss: 0.4301 | Train Accuracy: 0.8040
# 	Validation Loss: 0.4286 | Validation Accuracy: 0.8090
#
# Epoch: 230 | Number of Layers: 3
# 	Train Loss: 0.4184 | Train Accuracy: 0.8342
# 	Validation Loss: 0.4156 | Validation Accuracy: 0.8342
#
# Epoch: 240 | Number of Layers: 3
# 	Train Loss: 0.4045 | Train Accuracy: 0.8342
# 	Validation Loss: 0.4027 | Validation Accuracy: 0.8342
#
# Epoch: 250 | Number of Layers: 3
# 	Train Loss: 0.3913 | Train Accuracy: 0.8392
# 	Validation Loss: 0.3902 | Validation Accuracy: 0.8392
#
# Epoch: 260 | Number of Layers: 3
# 	Train Loss: 0.3789 | Train Accuracy: 0.8492
# 	Validation Loss: 0.3782 | Validation Accuracy: 0.8492
#
# Epoch: 270 | Number of Layers: 3
# 	Train Loss: 0.3696 | Train Accuracy: 0.8693
# 	Validation Loss: 0.3670 | Validation Accuracy: 0.8693
#
# Epoch: 280 | Number of Layers: 3
# 	Train Loss: 0.3576 | Train Accuracy: 0.8693
# 	Validation Loss: 0.3565 | Validation Accuracy: 0.8693
#
# Epoch: 290 | Number of Layers: 3
# 	Train Loss: 0.3480 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3466 | Validation Accuracy: 0.8693
#
# Epoch: 300 | Number of Layers: 3
# 	Train Loss: 0.3402 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3375 | Validation Accuracy: 0.8744
#
# Epoch: 310 | Number of Layers: 3
# 	Train Loss: 0.3303 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3291 | Validation Accuracy: 0.8744
#
# Epoch: 320 | Number of Layers: 3
# 	Train Loss: 0.3228 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3210 | Validation Accuracy: 0.8844
#
# Epoch: 330 | Number of Layers: 3
# 	Train Loss: 0.3159 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3137 | Validation Accuracy: 0.8844
#
# Epoch: 340 | Number of Layers: 3
# 	Train Loss: 0.3145 | Train Accuracy: 0.8844
# 	Validation Loss: 0.3069 | Validation Accuracy: 0.8844
#
# Epoch: 350 | Number of Layers: 3
# 	Train Loss: 0.3022 | Train Accuracy: 0.8894
# 	Validation Loss: 0.3005 | Validation Accuracy: 0.8894
#
# Epoch: 360 | Number of Layers: 3
# 	Train Loss: 0.2961 | Train Accuracy: 0.8945
# 	Validation Loss: 0.2944 | Validation Accuracy: 0.8995
#
# Epoch: 370 | Number of Layers: 3
# 	Train Loss: 0.2918 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2886 | Validation Accuracy: 0.9146
#
# Epoch: 380 | Number of Layers: 3
# 	Train Loss: 0.2850 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2830 | Validation Accuracy: 0.9146
#
# Epoch: 390 | Number of Layers: 3
# 	Train Loss: 0.2790 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2775 | Validation Accuracy: 0.9146
#
# Epoch: 400 | Number of Layers: 3
# 	Train Loss: 0.2732 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2722 | Validation Accuracy: 0.9146
#
# Epoch: 410 | Number of Layers: 3
# 	Train Loss: 0.2686 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2671 | Validation Accuracy: 0.9095
#
# Epoch: 420 | Number of Layers: 3
# 	Train Loss: 0.2641 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2620 | Validation Accuracy: 0.9146
#
# Epoch: 430 | Number of Layers: 3
# 	Train Loss: 0.2584 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2571 | Validation Accuracy: 0.9146
#
# Epoch: 440 | Number of Layers: 3
# 	Train Loss: 0.2545 | Train Accuracy: 0.9095
# 	Validation Loss: 0.2522 | Validation Accuracy: 0.9146
#
# Epoch: 450 | Number of Layers: 3
# 	Train Loss: 0.2488 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2474 | Validation Accuracy: 0.9146
#
# Epoch: 460 | Number of Layers: 3
# 	Train Loss: 0.2450 | Train Accuracy: 0.9146
# 	Validation Loss: 0.2426 | Validation Accuracy: 0.9196
#
# Epoch: 470 | Number of Layers: 3
# 	Train Loss: 0.2404 | Train Accuracy: 0.9196
# 	Validation Loss: 0.2377 | Validation Accuracy: 0.9196
#
# Epoch: 480 | Number of Layers: 3
# 	Train Loss: 0.2346 | Train Accuracy: 0.9196
# 	Validation Loss: 0.2328 | Validation Accuracy: 0.9196
#
# Epoch: 490 | Number of Layers: 3
# 	Train Loss: 0.2306 | Train Accuracy: 0.9246
# 	Validation Loss: 0.2280 | Validation Accuracy: 0.9296
#
# Epoch: 500 | Number of Layers: 3
# 	Train Loss: 0.2255 | Train Accuracy: 0.9296
# 	Validation Loss: 0.2233 | Validation Accuracy: 0.9296
#
# Epoch: 510 | Number of Layers: 3
# 	Train Loss: 0.2202 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2186 | Validation Accuracy: 0.9347
#
# Epoch: 520 | Number of Layers: 3
# 	Train Loss: 0.2156 | Train Accuracy: 0.9347
# 	Validation Loss: 0.2139 | Validation Accuracy: 0.9347
#
# Epoch: 530 | Number of Layers: 3
# 	Train Loss: 0.2115 | Train Accuracy: 0.9397
# 	Validation Loss: 0.2091 | Validation Accuracy: 0.9397
#
# Epoch: 540 | Number of Layers: 3
# 	Train Loss: 0.2065 | Train Accuracy: 0.9447
# 	Validation Loss: 0.2043 | Validation Accuracy: 0.9397
#
# Epoch: 550 | Number of Layers: 3
# 	Train Loss: 0.2012 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1995 | Validation Accuracy: 0.9447
#
# Epoch: 560 | Number of Layers: 3
# 	Train Loss: 0.1967 | Train Accuracy: 0.9447
# 	Validation Loss: 0.1948 | Validation Accuracy: 0.9497
#
# Epoch: 570 | Number of Layers: 3
# 	Train Loss: 0.1915 | Train Accuracy: 0.9548
# 	Validation Loss: 0.1901 | Validation Accuracy: 0.9497
#
# Epoch: 580 | Number of Layers: 3
# 	Train Loss: 0.1868 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1855 | Validation Accuracy: 0.9497
#
# Epoch: 590 | Number of Layers: 3
# 	Train Loss: 0.1823 | Train Accuracy: 0.9497
# 	Validation Loss: 0.1809 | Validation Accuracy: 0.9497
#
# Epoch: 0 | Number of Layers: 4
# 	Train Loss: 0.6462 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6461 | Validation Accuracy: 0.6834
#
# Epoch: 10 | Number of Layers: 4
# 	Train Loss: 0.6407 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6401 | Validation Accuracy: 0.6834
#
# Epoch: 20 | Number of Layers: 4
# 	Train Loss: 0.6362 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6356 | Validation Accuracy: 0.6834
#
# Epoch: 30 | Number of Layers: 4
# 	Train Loss: 0.6322 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6323 | Validation Accuracy: 0.6834
#
# Epoch: 40 | Number of Layers: 4
# 	Train Loss: 0.6296 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6298 | Validation Accuracy: 0.6834
#
# Epoch: 50 | Number of Layers: 4
# 	Train Loss: 0.6295 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6280 | Validation Accuracy: 0.6834
#
# Epoch: 60 | Number of Layers: 4
# 	Train Loss: 0.6272 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6265 | Validation Accuracy: 0.6834
#
# Epoch: 70 | Number of Layers: 4
# 	Train Loss: 0.6271 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6254 | Validation Accuracy: 0.6834
#
# Epoch: 80 | Number of Layers: 4
# 	Train Loss: 0.6242 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6246 | Validation Accuracy: 0.6834
#
# Epoch: 90 | Number of Layers: 4
# 	Train Loss: 0.6245 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6239 | Validation Accuracy: 0.6834
#
# Epoch: 100 | Number of Layers: 4
# 	Train Loss: 0.6240 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6233 | Validation Accuracy: 0.6834
#
# Epoch: 110 | Number of Layers: 4
# 	Train Loss: 0.6235 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6228 | Validation Accuracy: 0.6834
#
# Epoch: 120 | Number of Layers: 4
# 	Train Loss: 0.6242 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6223 | Validation Accuracy: 0.6834
#
# Epoch: 130 | Number of Layers: 4
# 	Train Loss: 0.6226 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6219 | Validation Accuracy: 0.6834
#
# Epoch: 140 | Number of Layers: 4
# 	Train Loss: 0.6234 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6215 | Validation Accuracy: 0.6834
#
# Epoch: 150 | Number of Layers: 4
# 	Train Loss: 0.6218 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6211 | Validation Accuracy: 0.6834
#
# Epoch: 160 | Number of Layers: 4
# 	Train Loss: 0.6239 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6207 | Validation Accuracy: 0.6834
#
# Epoch: 170 | Number of Layers: 4
# 	Train Loss: 0.6211 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6203 | Validation Accuracy: 0.6834
#
# Epoch: 180 | Number of Layers: 4
# 	Train Loss: 0.6195 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6199 | Validation Accuracy: 0.6834
#
# Epoch: 190 | Number of Layers: 4
# 	Train Loss: 0.6215 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6195 | Validation Accuracy: 0.6834
#
# Epoch: 200 | Number of Layers: 4
# 	Train Loss: 0.6186 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6191 | Validation Accuracy: 0.6834
#
# Epoch: 210 | Number of Layers: 4
# 	Train Loss: 0.6194 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6186 | Validation Accuracy: 0.6834
#
# Epoch: 220 | Number of Layers: 4
# 	Train Loss: 0.6177 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6181 | Validation Accuracy: 0.6834
#
# Epoch: 230 | Number of Layers: 4
# 	Train Loss: 0.6196 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6176 | Validation Accuracy: 0.6834
#
# Epoch: 240 | Number of Layers: 4
# 	Train Loss: 0.6202 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6170 | Validation Accuracy: 0.6834
#
# Epoch: 250 | Number of Layers: 4
# 	Train Loss: 0.6171 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6163 | Validation Accuracy: 0.6834
#
# Epoch: 260 | Number of Layers: 4
# 	Train Loss: 0.6175 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6155 | Validation Accuracy: 0.6834
#
# Epoch: 270 | Number of Layers: 4
# 	Train Loss: 0.6153 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6145 | Validation Accuracy: 0.6834
#
# Epoch: 280 | Number of Layers: 4
# 	Train Loss: 0.6156 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6135 | Validation Accuracy: 0.6834
#
# Epoch: 290 | Number of Layers: 4
# 	Train Loss: 0.6131 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6123 | Validation Accuracy: 0.6834
#
# Epoch: 300 | Number of Layers: 4
# 	Train Loss: 0.6106 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6110 | Validation Accuracy: 0.6834
#
# Epoch: 310 | Number of Layers: 4
# 	Train Loss: 0.6103 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6094 | Validation Accuracy: 0.6834
#
# Epoch: 320 | Number of Layers: 4
# 	Train Loss: 0.6086 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6077 | Validation Accuracy: 0.6834
#
# Epoch: 330 | Number of Layers: 4
# 	Train Loss: 0.6054 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6057 | Validation Accuracy: 0.6834
#
# Epoch: 340 | Number of Layers: 4
# 	Train Loss: 0.6053 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6032 | Validation Accuracy: 0.6834
#
# Epoch: 350 | Number of Layers: 4
# 	Train Loss: 0.6025 | Train Accuracy: 0.6834
# 	Validation Loss: 0.6003 | Validation Accuracy: 0.6834
#
# Epoch: 360 | Number of Layers: 4
# 	Train Loss: 0.5966 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5968 | Validation Accuracy: 0.6834
#
# Epoch: 370 | Number of Layers: 4
# 	Train Loss: 0.5927 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5927 | Validation Accuracy: 0.6834
#
# Epoch: 380 | Number of Layers: 4
# 	Train Loss: 0.5889 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5878 | Validation Accuracy: 0.6834
#
# Epoch: 390 | Number of Layers: 4
# 	Train Loss: 0.5842 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5818 | Validation Accuracy: 0.6834
#
# Epoch: 400 | Number of Layers: 4
# 	Train Loss: 0.5758 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5747 | Validation Accuracy: 0.6834
#
# Epoch: 410 | Number of Layers: 4
# 	Train Loss: 0.5667 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5663 | Validation Accuracy: 0.6834
#
# Epoch: 420 | Number of Layers: 4
# 	Train Loss: 0.5576 | Train Accuracy: 0.6834
# 	Validation Loss: 0.5563 | Validation Accuracy: 0.6834
#
# Epoch: 430 | Number of Layers: 4
# 	Train Loss: 0.5461 | Train Accuracy: 0.6935
# 	Validation Loss: 0.5446 | Validation Accuracy: 0.6935
#
# Epoch: 440 | Number of Layers: 4
# 	Train Loss: 0.5320 | Train Accuracy: 0.6985
# 	Validation Loss: 0.5306 | Validation Accuracy: 0.6985
#
# Epoch: 450 | Number of Layers: 4
# 	Train Loss: 0.5158 | Train Accuracy: 0.7186
# 	Validation Loss: 0.5145 | Validation Accuracy: 0.7186
#
# Epoch: 460 | Number of Layers: 4
# 	Train Loss: 0.4971 | Train Accuracy: 0.7588
# 	Validation Loss: 0.4965 | Validation Accuracy: 0.7588
#
# Epoch: 470 | Number of Layers: 4
# 	Train Loss: 0.4781 | Train Accuracy: 0.7889
# 	Validation Loss: 0.4768 | Validation Accuracy: 0.7889
#
# Epoch: 480 | Number of Layers: 4
# 	Train Loss: 0.4571 | Train Accuracy: 0.8090
# 	Validation Loss: 0.4562 | Validation Accuracy: 0.8090
#
# Epoch: 490 | Number of Layers: 4
# 	Train Loss: 0.4376 | Train Accuracy: 0.8442
# 	Validation Loss: 0.4358 | Validation Accuracy: 0.8392
#
# Epoch: 500 | Number of Layers: 4
# 	Train Loss: 0.4173 | Train Accuracy: 0.8442
# 	Validation Loss: 0.4164 | Validation Accuracy: 0.8492
#
# Epoch: 510 | Number of Layers: 4
# 	Train Loss: 0.4001 | Train Accuracy: 0.8543
# 	Validation Loss: 0.3988 | Validation Accuracy: 0.8593
#
# Epoch: 520 | Number of Layers: 4
# 	Train Loss: 0.3851 | Train Accuracy: 0.8543
# 	Validation Loss: 0.3830 | Validation Accuracy: 0.8543
#
# Epoch: 530 | Number of Layers: 4
# 	Train Loss: 0.3715 | Train Accuracy: 0.8643
# 	Validation Loss: 0.3690 | Validation Accuracy: 0.8643
#
# Epoch: 540 | Number of Layers: 4
# 	Train Loss: 0.3581 | Train Accuracy: 0.8693
# 	Validation Loss: 0.3566 | Validation Accuracy: 0.8693
#
# Epoch: 550 | Number of Layers: 4
# 	Train Loss: 0.3475 | Train Accuracy: 0.8693
# 	Validation Loss: 0.3457 | Validation Accuracy: 0.8693
#
# Epoch: 560 | Number of Layers: 4
# 	Train Loss: 0.3373 | Train Accuracy: 0.8693
# 	Validation Loss: 0.3357 | Validation Accuracy: 0.8693
#
# Epoch: 570 | Number of Layers: 4
# 	Train Loss: 0.3278 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3264 | Validation Accuracy: 0.8744
#
# Epoch: 580 | Number of Layers: 4
# 	Train Loss: 0.3192 | Train Accuracy: 0.8744
# 	Validation Loss: 0.3178 | Validation Accuracy: 0.8794
#
# Epoch: 590 | Number of Layers: 4
# 	Train Loss: 0.3129 | Train Accuracy: 0.8794
# 	Validation Loss: 0.3097 | Validation Accuracy: 0.8794

# %%
plt.figure(figsize=(10,6))

colors = ['darkblue', 'darkred', 'darkgreen']
light_colors = ['skyblue', 'salmon', 'limegreen']
layers = [2, 3, 4]

for i, num_layer in enumerate(layers):

    start = i * num_epochs
    end = (i + 1) * num_epochs

    # Train Loss
    plt.plot(
        range(num_epochs),
        loss_train_hist[start:end],
        color=colors[i],
        linewidth=2,
        marker='o',
        label=f'train_layers={num_layer}'
    )

    # Validation Loss
    plt.plot(
        range(num_epochs),
        loss_valid_hist[start:end],
        color=light_colors[i],
        linewidth=2,
        linestyle='--',
        marker='x',
        label=f'valid_layers={num_layer}'
    )

plt.title("Effect of Number of Hidden Layers on Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.grid(True, linestyle=':')
plt.legend()
plt.tight_layout()

plt.savefig("../images/loss_layers.png", bbox_inches='tight')

plt.show()
