# %% [markdown]
# #### Libraries

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
import torch.nn as nn
import torch.optim as optim
from torchmetrics import Accuracy

from sklearn.model_selection import train_test_split
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

# %% [markdown]
# #### Dataset

# %%
# Extract dataset.zip
with zipfile.ZipFile('dataset.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
# Read Dataset
df = pd.read_csv('./dataset/train.csv')
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  55.0        0                      7861         0                 38
# 1  65.0        0                       146         0                 20
# 2  50.0        1                       111         0                 20
# 3  65.0        1                       160         1                 20
# 4  75.0        1                       246         0                 15
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    0  263358.03               1.1           136    1
# 1                    0  162000.00               1.3           129    1
# 2                    0  210000.00               1.9           137    1
# 3                    0  327000.00               2.7           116    0
# 4                    0  127000.00               1.2           137    1
#
#    smoking  time  DEATH_EVENT
# 0        0     6            1
# 1        1     7            1
# 2        0     7            1
# 3        0     8            1
# 4        0    10            1

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  249.000000  249.000000                249.000000  249.000000
# mean    59.906293    0.409639                565.594378    0.393574
# std     11.539249    0.492757                927.736276    0.489526
# min     40.000000    0.000000                 30.000000    0.000000
# 25%     50.000000    0.000000                118.000000    0.000000
# 50%     60.000000    0.000000                246.000000    0.000000
# 75%     68.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         249.000000           249.000000     249.000000
# mean           38.405622             0.365462  257685.512932
# std            11.949833             0.482529   89331.766264
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  213000.000000
# 50%            38.000000             0.000000  255000.000000
# 75%            45.000000             1.000000  297000.000000
# max            80.000000             1.000000  742000.000000
#
#        serum_creatinine  serum_sodium         sex     smoking        time  \
# count        249.000000    249.000000  249.000000  249.000000  249.000000
# mean           1.385783    136.526104    0.630522    0.313253  130.481928
# std            1.061953      4.326438    0.483636    0.464750   77.274181
# min            0.500000    113.000000    0.000000    0.000000    6.000000
# 25%            0.900000    134.000000    0.000000    0.000000   73.000000
# 50%            1.100000    137.000000    1.000000    0.000000  113.000000
# 75%            1.400000    139.000000    1.000000    1.000000  205.000000
# max            9.400000    148.000000    1.000000    1.000000  285.000000
#
#        DEATH_EVENT
# count   249.000000
# mean      0.313253
# std       0.464750
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
# Correlation analysis heatmap

corr_with_target = df.corr()['DEATH_EVENT'].sort_values(ascending=False)
sorted_features = corr_with_target.index.tolist()
corr_sorted = df[sorted_features].corr()


plt.figure(figsize=(18, 16))
sns.heatmap(corr_sorted, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Feature Correlation Matrix (Sorted by Correlation with Target)', fontsize=30, pad=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.show()


print("Correlation with DEATH_EVENT:")
print(corr_with_target)
# Out:
# Correlation with DEATH_EVENT:
# DEATH_EVENT                 1.000000
# serum_creatinine            0.326138
# age                         0.273166
# anaemia                     0.088886
# high_blood_pressure         0.044843
# creatinine_phosphokinase    0.031485
# diabetes                    0.005338
# sex                        -0.021182
# smoking                    -0.026766
# platelets                  -0.063508
# serum_sodium               -0.256762
# ejection_fraction          -0.268376
# time                       -0.521597
# Name: DEATH_EVENT, dtype: float64

# %%
x = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']
x.shape, y.shape
# Out:
# ((249, 12), (249,))

# %%
# Splitting the data into training and testing sets
x_train, x_valid, y_train, y_valid = train_test_split(x, y, train_size=0.8, random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_valid.shape)
print(y_valid.shape)
# Out:
# (199, 12)
# (199,)
# (50, 12)
# (50,)

# %% [markdown]
# #### Preprocess

# %%
x_train = torch.FloatTensor(x_train.values)
y_train = torch.FloatTensor(y_train.values)

x_valid = torch.FloatTensor(x_valid.values)
y_valid = torch.FloatTensor(y_valid.values)

# %%
mu = torch.mean(x_train, dim=0)
std = torch.std(x_train, dim=0)

x_train = (x_train - mu) / std
x_valid = (x_valid - mu) / std

# %% [markdown]
# #### Dataloader

# %%
train_dataset = TensorDataset(x_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

valid_dataset = TensorDataset(x_train, y_train)
valid_loader = DataLoader(train_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# #### MLP Model

# %%
in_features = 12
out_features = 1
h1 = 64
h2 = 32

model = nn.Sequential(nn.Linear(in_features, h1),
                      nn.ReLU(),
                      nn.Linear(h1, h2),
                      nn.ReLU(),
                      nn.Linear(h2, out_features),
                      nn.Sigmoid())

model
# Out:
# Sequential(
#   (0): Linear(in_features=12, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=32, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=32, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# #### Loss function & Optimizer

# %%
loss_fn = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# #### Utils

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# #### Train

# %%
loss_train_hist = []
loss_valid_hist = []

acc_train_hist = []
acc_valid_hist = []

# %%
num_epochs = 300

for epoch in range(num_epochs):

    # train
    loss_train = AverageMeter()
    acc_train = Accuracy(task='binary')
    for inputs, targets in train_loader:
        outputs = model(inputs)
        loss = loss_fn(outputs.squeeze(), targets)

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        loss_train.update(loss.item(), len(targets))
        acc_train(outputs.squeeze(), targets.int())


    loss_train_hist.append(loss_train.avg)
    acc_train_hist.append(acc_train.compute().cpu())

    # validation
    with torch.no_grad():
        loss_valid = AverageMeter()
        acc_valid = Accuracy(task='binary')
        for inputs, targets in valid_loader:
            outputs = model(inputs)

            loss = loss_fn(outputs.squeeze(), targets)
            loss_valid.update(loss.item(), len(targets))

            acc_valid(outputs.squeeze(), targets.int())


    loss_valid_hist.append(loss_valid.avg)
    acc_valid_hist.append(acc_valid.compute().cpu())


    if epoch % 10 == 0:
        print(f'Epoch {epoch}')
        print(f'\tTrain Loss = {loss_train.avg:.4f} | Train Accuracy: {acc_train.compute():.4f}')
        print(f'\tValid Loss = {loss_valid.avg:.4f} | Validation Accuracy: {acc_valid.compute():.4f} \n')
# Out:
# Epoch 0
# 	Train Loss = 0.6769 | Train Accuracy: 0.6332
# 	Valid Loss = 0.6584 | Validation Accuracy: 0.6834
#
# Epoch 10
# 	Train Loss = 0.4719 | Train Accuracy: 0.7789
# 	Valid Loss = 0.4584 | Validation Accuracy: 0.7940
#
# Epoch 20
# 	Train Loss = 0.3529 | Train Accuracy: 0.8693
# 	Valid Loss = 0.3439 | Validation Accuracy: 0.8744
#
# Epoch 30
# 	Train Loss = 0.3091 | Train Accuracy: 0.8945
# 	Valid Loss = 0.3002 | Validation Accuracy: 0.8945
#
# Epoch 40
# 	Train Loss = 0.2737 | Train Accuracy: 0.8995
# 	Valid Loss = 0.2635 | Validation Accuracy: 0.9045
#
# Epoch 50
# 	Train Loss = 0.2369 | Train Accuracy: 0.9246
# 	Valid Loss = 0.2261 | Validation Accuracy: 0.9397
#
# Epoch 60
# 	Train Loss = 0.2014 | Train Accuracy: 0.9397
# 	Valid Loss = 0.1913 | Validation Accuracy: 0.9447
#
# Epoch 70
# 	Train Loss = 0.1703 | Train Accuracy: 0.9447
# 	Valid Loss = 0.1603 | Validation Accuracy: 0.9548
#
# Epoch 80
# 	Train Loss = 0.1442 | Train Accuracy: 0.9598
# 	Valid Loss = 0.1334 | Validation Accuracy: 0.9598
#
# Epoch 90
# 	Train Loss = 0.1201 | Train Accuracy: 0.9698
# 	Valid Loss = 0.1099 | Validation Accuracy: 0.9698
#
# Epoch 100
# 	Train Loss = 0.0991 | Train Accuracy: 0.9749
# 	Valid Loss = 0.0898 | Validation Accuracy: 0.9849
#
# Epoch 110
# 	Train Loss = 0.0819 | Train Accuracy: 0.9799
# 	Valid Loss = 0.0735 | Validation Accuracy: 0.9799
#
# Epoch 120
# 	Train Loss = 0.0677 | Train Accuracy: 0.9849
# 	Valid Loss = 0.0605 | Validation Accuracy: 0.9899
#
# Epoch 130
# 	Train Loss = 0.0562 | Train Accuracy: 0.9950
# 	Valid Loss = 0.0502 | Validation Accuracy: 0.9899
#
# Epoch 140
# 	Train Loss = 0.0469 | Train Accuracy: 0.9899
# 	Valid Loss = 0.0407 | Validation Accuracy: 0.9950
#
# Epoch 150
# 	Train Loss = 0.0395 | Train Accuracy: 0.9899
# 	Valid Loss = 0.0347 | Validation Accuracy: 0.9950
#
# Epoch 160
# 	Train Loss = 0.0330 | Train Accuracy: 0.9950
# 	Valid Loss = 0.0294 | Validation Accuracy: 0.9950
#
# Epoch 170
# 	Train Loss = 0.0290 | Train Accuracy: 0.9950
# 	Valid Loss = 0.0251 | Validation Accuracy: 0.9950
#
# Epoch 180
# 	Train Loss = 0.0248 | Train Accuracy: 0.9950
# 	Valid Loss = 0.0216 | Validation Accuracy: 0.9950
#
# Epoch 190
# 	Train Loss = 0.0213 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0186 | Validation Accuracy: 1.0000
#
# Epoch 200
# 	Train Loss = 0.0190 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0163 | Validation Accuracy: 1.0000
#
# Epoch 210
# 	Train Loss = 0.0168 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0147 | Validation Accuracy: 1.0000
#
# Epoch 220
# 	Train Loss = 0.0145 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0130 | Validation Accuracy: 1.0000
#
# Epoch 230
# 	Train Loss = 0.0130 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0114 | Validation Accuracy: 1.0000
#
# Epoch 240
# 	Train Loss = 0.0116 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0102 | Validation Accuracy: 1.0000
#
# Epoch 250
# 	Train Loss = 0.0101 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0092 | Validation Accuracy: 1.0000
#
# Epoch 260
# 	Train Loss = 0.0091 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0084 | Validation Accuracy: 1.0000
#
# Epoch 270
# 	Train Loss = 0.0084 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0076 | Validation Accuracy: 1.0000
#
# Epoch 280
# 	Train Loss = 0.0075 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0070 | Validation Accuracy: 1.0000
#
# Epoch 290
# 	Train Loss = 0.0069 | Train Accuracy: 1.0000
# 	Valid Loss = 0.0065 | Validation Accuracy: 1.0000

# %%
plt.plot(range(num_epochs), loss_train_hist, 'b-', label="Train")
plt.plot(range(num_epochs), loss_valid_hist, 'r-', label="Validation")

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()
plt.show()

# %%
# plot acc_epoch
plt.plot(range(num_epochs), acc_train_hist, 'b-', label="Train")
plt.plot(range(num_epochs), acc_valid_hist, 'r-', label="Validation")

plt.title("Training and Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()
